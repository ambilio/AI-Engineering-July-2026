# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
import kagglehub
import os

# Download datasets
nolanbconaway_pitchfork_data_path = kagglehub.dataset_download('nolanbconaway/pitchfork-data')
datasnaek_chess_path = kagglehub.dataset_download('datasnaek/chess')
nasa_kepler_exoplanet_search_results_path = kagglehub.dataset_download('nasa/kepler-exoplanet-search-results')
residentmario_things_on_reddit_path = kagglehub.dataset_download('residentmario/things-on-reddit')
zynicide_wine_reviews_path = kagglehub.dataset_download('zynicide/wine-reviews')
residentmario_ramen_ratings_path = kagglehub.dataset_download('residentmario/ramen-ratings')
dansbecker_powerlifting_database_path = kagglehub.dataset_download('dansbecker/powerlifting-database')
datasnaek_youtube_new_path = kagglehub.dataset_download('datasnaek/youtube-new')
rtatman_188_million_us_wildfires_path = kagglehub.dataset_download('rtatman/188-million-us-wildfires')
jpmiller_publicassistance_path = kagglehub.dataset_download('jpmiller/publicassistance')

# Mapping of dataset names to their download paths
datasets = {
    'pitchfork-data': nolanbconaway_pitchfork_data_path,
    'chess': datasnaek_chess_path,
    'kepler-exoplanet-search-results': nasa_kepler_exoplanet_search_results_path,
    'things-on-reddit': residentmario_things_on_reddit_path,
    'wine-reviews': zynicide_wine_reviews_path,
    'ramen-ratings': residentmario_ramen_ratings_path,
    'powerlifting-database': dansbecker_powerlifting_database_path,
    'youtube-new': datasnaek_youtube_new_path,
    '188-million-us-wildfires': rtatman_188_million_us_wildfires_path,
    'publicassistance': jpmiller_publicassistance_path
}

# Create the /input directory if it doesn't exist
input_dir = '../input'
os.makedirs(input_dir, exist_ok=True)

# Create symbolic links for each dataset
for name, path in datasets.items():
    target_link = os.path.join(input_dir, name)
    if not os.path.exists(target_link):
        os.symlink(path, target_link)

print('Data source import and linking complete.')
# Out:
# Using Colab cache for faster access to the 'pitchfork-data' dataset.
# Downloading to /root/.cache/kagglehub/datasets/datasnaek/chess/1.archive...
# 100%|██████████| 2.77M/2.77M [00:01<00:00, 2.27MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/nasa/kepler-exoplanet-search-results/2.archive...
# 100%|██████████| 1.16M/1.16M [00:01<00:00, 1.13MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/residentmario/things-on-reddit/1.archive...
# 100%|██████████| 16.0M/16.0M [00:01<00:00, 8.57MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/zynicide/wine-reviews/4.archive...
# 100%|██████████| 50.9M/50.9M [00:03<00:00, 15.1MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/residentmario/ramen-ratings/1.archive...
# 100%|██████████| 39.8k/39.8k [00:00<00:00, 1.23MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/dansbecker/powerlifting-database/1.archive...
# 100%|██████████| 8.85M/8.85M [00:01<00:00, 5.73MB/s]
# Extracting files...
# Using Colab cache for faster access to the 'youtube-new' dataset.
# Downloading to /root/.cache/kagglehub/datasets/rtatman/188-million-us-wildfires/2.archive...
# 100%|██████████| 168M/168M [00:09<00:00, 19.4MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/jpmiller/publicassistance/9.archive...
# 100%|██████████| 297k/297k [00:00<00:00, 435kB/s]
# Extracting files...
# Data source import and linking complete.

# %% [markdown]
# # Introduction
#
# In these exercises we'll apply groupwise analysis to our dataset.
#
# Run the code cell below to load the data before running the exercises.

# %%
# !pip install git+https://github.com/Kaggle/learntools.git
# Out:
# Collecting git+https://github.com/Kaggle/learntools.git
#   Cloning https://github.com/Kaggle/learntools.git to /tmp/pip-req-build-wa4ws0l3
#   Running command git clone --filter=blob:none --quiet https://github.com/Kaggle/learntools.git /tmp/pip-req-build-wa4ws0l3
#   Resolved https://github.com/Kaggle/learntools.git to commit 8a8d4450a699c864febc419fb27ec41443a5942b
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: learntools
#   Building wheel for learntools (setup.py) ... done
#   Created wheel for learntools: filename=learntools-0.3.5-py3-none-any.whl size=269683 sha256=488894c0455ab1255d14607b3e47a6f593b564d57b2af68edb555c644793430d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-okdykrv5/wheels/3e/56/95/47a8734b7e520ce6a601b2d09b8e0714eac8b3d59669123c80
# Successfully built learntools
# Installing collected packages: learntools
# Successfully installed learntools-0.3.5

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
#pd.set_option("display.max_rows", 5)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.grouping_and_sorting import *
print("Setup complete.")
# Out:
# Setup complete.
# /usr/local/lib/python3.12/dist-packages/learntools/pandas/grouping_and_sorting.py:29: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   _expected = reviews.groupby('variety').price.agg([min, max])
# /usr/local/lib/python3.12/dist-packages/learntools/pandas/grouping_and_sorting.py:29: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   _expected = reviews.groupby('variety').price.agg([min, max])
# /usr/local/lib/python3.12/dist-packages/learntools/pandas/grouping_and_sorting.py:35: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   _expected = reviews.groupby('variety').price.agg([min, max]).sort_values(by=['min', 'max'], ascending=False)
# /usr/local/lib/python3.12/dist-packages/learntools/pandas/grouping_and_sorting.py:35: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   _expected = reviews.groupby('variety').price.agg([min, max]).sort_values(by=['min', 'max'], ascending=False)

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# Who are the most common wine reviewers in the dataset? Create a `Series` whose index is the `taster_twitter_handle` category from the dataset, and whose values count how many reviews each person wrote.

# %%
# Your code here
reviews_written = ____

# Check your answer
q1.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `reviews_written`

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that `4.0` dollars is at the top and `3300.0` dollars is at the bottom).

# %%
best_rating_per_price = ____

# Check your answer
q2.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `best_rating_per_price`

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof.

# %%
price_extremes = ____

# Check your answer
q3.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `price_extremes`

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sorted_varieties = ____

# Check your answer
q4.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `sorted_varieties`

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# ## 5.
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
reviewer_mean_ratings = ____

# Check your answer
q5.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `reviewer_mean_ratings`

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# Are there significant differences in the average scores assigned by the various reviewers? Run the cell below to use the `describe()` method to see a summary of the range of values.

# %%
reviewer_mean_ratings.describe()

# %% [markdown]
# ## 6.
# What combination of countries and varieties are most common? Create a `Series` whose index is a `MultiIndex`of `{country, variety}` pairs. For example, a pinot noir produced in the US should map to `{"US", "Pinot Noir"}`. Sort the values in the `Series` in descending order based on wine count.

# %%
country_variety_counts = ____

# Check your answer
q6.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `country_variety_counts`

# %%
#q6.hint()
#q6.solution()
