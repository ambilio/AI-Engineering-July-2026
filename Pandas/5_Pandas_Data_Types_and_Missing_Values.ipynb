# %%
import kagglehub
import os
import shutil

# Download datasets
nolanbconaway_pitchfork_data_path = kagglehub.dataset_download('nolanbconaway/pitchfork-data')
datasnaek_chess_path = kagglehub.dataset_download('datasnaek/chess')
nasa_kepler_exoplanet_search_results_path = kagglehub.dataset_download('nasa/kepler-exoplanet-search-results')
residentmario_things_on_reddit_path = kagglehub.dataset_download('residentmario/things-on-reddit')
zynicide_wine_reviews_path = kagglehub.dataset_download('zynicide/wine-reviews')
residentmario_ramen_ratings_path = kagglehub.dataset_download('residentmario/ramen-ratings')
dansbecker_powerlifting_database_path = kagglehub.dataset_download('dansbecker/powerlifting-database')
datasnaek_youtube_new_path = kagglehub.dataset_download('datasnaek/youtube-new')
rtatman_188_million_us_wildfires_path = kagglehub.dataset_download('rtatman/188-million-us-wildfires')
jpmiller_publicassistance_path = kagglehub.dataset_download('jpmiller/publicassistance')

# Map Kaggle dataset names to their local download paths
datasets = {
    'pitchfork-data': nolanbconaway_pitchfork_data_path,
    'chess': datasnaek_chess_path,
    'kepler-exoplanet-search-results': nasa_kepler_exoplanet_search_results_path,
    'things-on-reddit': residentmario_things_on_reddit_path,
    'wine-reviews': zynicide_wine_reviews_path,
    'ramen-ratings': residentmario_ramen_ratings_path,
    'powerlifting-database': dansbecker_powerlifting_database_path,
    'youtube-new': datasnaek_youtube_new_path,
    '188-million-us-wildfires': rtatman_188_million_us_wildfires_path,
    'publicassistance': jpmiller_publicassistance_path
}

# Create the /input directory if it doesn't exist
input_dir = '../input'
os.makedirs(input_dir, exist_ok=True)

# Create symbolic links for each dataset
for name, path in datasets.items():
    dest = os.path.join(input_dir, name)
    if not os.path.exists(dest):
        os.symlink(path, dest)

print('Data source import and linking complete.')
# Out:
# Downloading to /root/.cache/kagglehub/datasets/nolanbconaway/pitchfork-data/1.archive...
# 100%|██████████| 33.3M/33.3M [00:00<00:00, 80.1MB/s]
# Extracting files...
# Using Colab cache for faster access to the 'chess' dataset.
# Downloading to /root/.cache/kagglehub/datasets/nasa/kepler-exoplanet-search-results/2.archive...
# 100%|██████████| 1.16M/1.16M [00:00<00:00, 90.5MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/residentmario/things-on-reddit/1.archive...
# 100%|██████████| 16.0M/16.0M [00:00<00:00, 92.5MB/s]
# Extracting files...
# Using Colab cache for faster access to the 'wine-reviews' dataset.
# Downloading to /root/.cache/kagglehub/datasets/residentmario/ramen-ratings/1.archive...
# 100%|██████████| 39.8k/39.8k [00:00<00:00, 36.7MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/dansbecker/powerlifting-database/1.archive...
# 100%|██████████| 8.85M/8.85M [00:00<00:00, 70.7MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/datasnaek/youtube-new/115.archive...
# 100%|██████████| 201M/201M [00:01<00:00, 150MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/rtatman/188-million-us-wildfires/2.archive...
# 100%|██████████| 168M/168M [00:01<00:00, 166MB/s]
# Extracting files...
# Downloading to /root/.cache/kagglehub/datasets/jpmiller/publicassistance/9.archive...
# 100%|██████████| 297k/297k [00:00<00:00, 32.3MB/s]
# Extracting files...
# Data source import and linking complete.

# %% [markdown]
# # Introduction
#
# Run the following cell to load your data and some utility functions.

# %%
# !pip install git+https://github.com/Kaggle/learntools.git
# Out:
# Collecting git+https://github.com/Kaggle/learntools.git
#   Cloning https://github.com/Kaggle/learntools.git to /tmp/pip-req-build-59pebqw1
#   Running command git clone --filter=blob:none --quiet https://github.com/Kaggle/learntools.git /tmp/pip-req-build-59pebqw1
#   Resolved https://github.com/Kaggle/learntools.git to commit 8a8d4450a699c864febc419fb27ec41443a5942b
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: learntools
#   Building wheel for learntools (setup.py) ... done
#   Created wheel for learntools: filename=learntools-0.3.5-py3-none-any.whl size=269683 sha256=782e307a129d3c68301011200226761d47bab4a88b8eb2f1bde72b2e1289ab3c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-alcvya1n/wheels/3e/56/95/47a8734b7e520ce6a601b2d09b8e0714eac8b3d59669123c80
# Successfully built learntools
# Installing collected packages: learntools
# Successfully installed learntools-0.3.5

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.data_types_and_missing_data import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# What is the data type of the `points` column in the dataset?

# %%
# Your code here
dtype = ____

# Check your answer
q1.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `dtype`

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# Create a Series from entries in the `points` column, but convert the entries to strings. Hint: strings are `str` in native Python.

# %%
point_strings = ____

# Check your answer
q2.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `point_strings`

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# Sometimes the price column is null. How many reviews in the dataset are missing a price?

# %%
n_missing_prices = ____

# Check your answer
q3.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `n_missing_prices`

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the `region_1` field. This field is often missing data, so replace missing values with `Unknown`. Sort in descending order.  Your output should look something like this:
#
# ```
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
reviews_per_region = ____

# Check your answer
q4.check()
# Out:
# Check: When you've updated the starter code, `check()` will tell you whether your code is correct. You need to update the code that creates variable `reviews_per_region`

# %%
#q4.hint()
#q4.solution()
